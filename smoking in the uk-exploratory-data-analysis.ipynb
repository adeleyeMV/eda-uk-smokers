# %% [markdown]
# # Important library:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Load the dataset of smokers in london::

# %%
smokers=pd.read_csv("/kaggle/input/uk-smoking-data/smoking.csvC:\Users\youssef\Desktop\instant_Ai\datasets\UKsmoking\smoking.csv")
smokers.head()
# Out:
#    gender  age marital_status highest_qualification nationality ethnicity  \
# 0    Male   38       Divorced      No Qualification     British     White
# 1  Female   42         Single      No Qualification     British     White
# 2    Male   40        Married                Degree     English     White
# 3  Female   40        Married                Degree     English     White
# 4  Female   39        Married          GCSE/O Level     British     White
#
#        gross_income     region smoke  amt_weekends  amt_weekdays     type
# 0    2,600 to 5,200  The North    No           NaN           NaN      NaN
# 1       Under 2,600  The North   Yes          12.0          12.0  Packets
# 2  28,600 to 36,400  The North    No           NaN           NaN      NaN
# 3  10,400 to 15,600  The North    No           NaN           NaN      NaN
# 4    2,600 to 5,200  The North    No           NaN           NaN      NaN

# %% [markdown]
# # Cleaning the data:

# %% [markdown]
# - Information of the data set (columns name, non-null values count,type of each column:

# %%
smokers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# RangeIndex: 1691 entries, 0 to 1690
#
# Data columns (total 12 columns):
#
#  #   Column                 Non-Null Count  Dtype
#
# ---  ------                 --------------  -----
#
#  0   gender                 1691 non-null   object
#
#  1   age                    1691 non-null   int64
#
#  2   marital_status         1691 non-null   object
#
#  3   highest_qualification  1691 non-null   object
#
#  4   nationality            1691 non-null   object
#
#  5   ethnicity              1691 non-null   object
#
#  6   gross_income           1691 non-null   object
#
#  7   region                 1691 non-null   object
#
#  8   smoke                  1691 non-null   object
#
#  9   amt_weekends           421 non-null    float64
#
#  10  amt_weekdays           421 non-null    float64
#
#  11  type                   421 non-null    object
#
# dtypes: float64(2), int64(1), object(9)
#
# memory usage: 158.7+ KB

# %% [markdown]
# - check the null values in each column:

# %%
smokers.isnull().sum()
# Out:
# gender                      0
# age                         0
# marital_status              0
# highest_qualification       0
# nationality                 0
# ethnicity                   0
# gross_income                0
# region                      0
# smoke                       0
# amt_weekends             1270
# amt_weekdays             1270
# type                     1270
# dtype: int64

# %% [markdown]
# - Note in the data we can't remove he null values and i will fill the nan values why because the nan values , i can consider them , they mean people not smoking,

# %% [markdown]
# - check for the duplicated values in data

# %%
smokers.duplicated().sum()
# Out:
# 21

# %% [markdown]
# - remove the duplicated values

# %%
smokers.drop_duplicates(inplace=True)
smokers.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - check the uniique values in each column:

# %%
smokers.nunique()
# Out:
# gender                    2
# age                      79
# marital_status            5
# highest_qualification     8
# nationality               8
# ethnicity                 7
# gross_income             10
# region                    7
# smoke                     2
# amt_weekends             24
# amt_weekdays             24
# type                      4
# dtype: int64

# %% [markdown]
# - Name of each column:

# %%
columns=smokers.columns.tolist()
print(columns)
# Out:
# ['gender', 'age', 'marital_status', 'highest_qualification', 'nationality', 'ethnicity', 'gross_income', 'region', 'smoke', 'amt_weekends', 'amt_weekdays', 'type']

# %%
y=smokers['amt_weekends'].sum()
print("The total number of the cigarette smoked in weekends = ",y)
# Out:
# The total number of the cigarette smoked in weekends =  6909.0

# %%
x=smokers['amt_weekdays'].sum()
print("The total number of the cigarette smoked in weekdays = ",x)
# Out:
# The total number of the cigarette smoked in weekdays =  5789.0

# %%
z=smokers['age'].median()
print("The median age of the people in data =   ",z)
# Out:
# The median age of the people in data =    48.0

# %% [markdown]
# # the plot of wah column shows us the column has:

# %%
sns.histplot(smokers['age'], bins=50, kde=True)
plt.title('avrage ages of people')
plt.show()

# %%
colors = plt.cm.viridis(np.linspace(0, 1, 2))
smokers['gender'].value_counts().plot(kind='bar',color=colors)
plt.xticks(rotation=45) 
plt.title('gender of people')
plt.show()

# %%
colors = plt.cm.viridis(np.linspace(0, 1, 5))
smokers['marital_status'].value_counts().plot(kind='bar',color=colors)
plt.xticks(rotation=45) 
plt.title('marital_status of people')
plt.show()

# %% [markdown]
# - we can see from the plot the max number is married people in the data=800
# - the min number of people is separated <100

# %%
colors = plt.cm.viridis(np.linspace(0, 1,8))
smokers['highest_qualification'].value_counts().plot(kind='bar',color=colors)
plt.xticks(rotation=45) 
plt.title('highest_qualification of people')
plt.show()

# %% [markdown]
# - above 500 people are No qualification
# - under the 100 people are ONC/BTEC
# - the plot shows us each count of category in the highest_qualification column

# %%
colors = plt.cm.viridis(np.linspace(0, 1,8))
smokers['nationality'].value_counts().plot(kind='bar',color=colors)
plt.xticks(rotation=45) 
plt.title('nationality of people')
plt.show()

# %% [markdown]
# - we can see the plot shows us the nationality of each category in the column
# - many people are English people ,the number is 800 people, I think.

# %%
colors = plt.cm.viridis(np.linspace(0, 1,7))
smokers['ethnicity'].value_counts().plot(kind='bar',color=colors)
plt.xticks(rotation=45) 
plt.title('ethnicity of people')
plt.show()

# %% [markdown]
# - we can see the most people are white

# %%
colors = plt.cm.viridis(np.linspace(0, 1, 7))
smokers['gross_income'].value_counts().plot(kind='bar', color=colors)
plt.xticks(rotation=45) 
plt.title('gross of the peoples')
plt.show()

# %% [markdown]
# - the above 350 people are have gross income from 5200 to 10400

# %%
colors = plt.cm.viridis(np.linspace(0, 1,8))
smokers['region'].value_counts().plot(kind='bar',color=colors)
plt.xticks(rotation=45) 
plt.title('region of peoples')
plt.show()

# %% [markdown]
# - more 700 people in the data are in the Midlands & East Anglia ant The North

# %%
colors = plt.cm.viridis(np.linspace(0, 1,2))
smokers['smoke'].value_counts().plot(kind='bar',color=colors)
plt.xticks(rotation=45) 
plt.title('people smoke?')
plt.show()

# %% [markdown]
# - most people not smoke in the london

# %%
colors = plt.cm.viridis(np.linspace(0, 1,2))
smokers['amt_weekends'].fillna(0,inplace=True)
smokers['amt_weekends'].value_counts().plot(kind='bar',color=colors)
plt.xticks(rotation=45) 
plt.title('smoking in weekends')
plt.show()

# %%
colors = plt.cm.viridis(np.linspace(0, 1,2))
smokers['amt_weekdays'].fillna(0,inplace=True)
smokers['amt_weekdays'].value_counts().plot(kind='bar',color=colors)
plt.xticks(rotation=45) 
plt.title('smoking in the weekdays')
plt.show()

# %%
colors = plt.cm.viridis(np.linspace(0, 1,2))
smokers['type'].fillna('others',inplace=True)
smokers['type'].value_counts().plot(kind='bar',color=colors)
plt.xticks(rotation=45) 
plt.title('type of cigarettes') 
plt.show()

# %%
smokers.describe()
# Out:
#                age  amt_weekends  amt_weekdays
# count  1670.000000   1670.000000   1670.000000
# mean     49.707186      4.137126      3.466467
# std      18.687295      8.685491      7.605996
# min      16.000000      0.000000      0.000000
# 25%      34.000000      0.000000      0.000000
# 50%      48.000000      0.000000      0.000000
# 75%      65.000000      0.000000      0.000000
# max      97.000000     60.000000     55.000000

# %% [markdown]
# # This plots shows us the relations between important columns:

# %%
plt.figure(figsize=(20,20))
pd.crosstab(smokers.gender,smokers.smoke).plot(kind='bar',color=colors)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20,20))
pd.crosstab(smokers.marital_status,smokers.smoke).plot(kind='bar',color=colors)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20,20))
pd.crosstab(smokers.highest_qualification,smokers.smoke).plot(kind='bar',color=colors)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20,20))
pd.crosstab(smokers.nationality,smokers.smoke).plot(kind='bar',color=colors)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20,20))
pd.crosstab(smokers.ethnicity,smokers.smoke).plot(kind='bar',color=colors)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20,20))
pd.crosstab(smokers.gross_income,smokers.smoke).plot(kind='bar',color=colors)
plt.xticks(rotation=45)
plt.show()

# %%
smoking = smokers[smokers['smoke'] == 'Yes']

plt.figure(figsize=(20, 20))
colors = plt.cm.viridis(np.linspace(0, 1, 7))
pd.crosstab(smoking['amt_weekdays'], smoking['smoke']).plot(kind='bar', color=colors)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20, 20))
colors = plt.cm.viridis(np.linspace(0, 1, 7))
pd.crosstab(smoking['amt_weekends'], smoking['smoke']).plot(kind='bar', color=colors)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20, 20))
colors = plt.cm.viridis(np.linspace(0, 1, ))
pd.crosstab(smokers['nationality'], smoking['gender']).plot(kind='barh',color=colors )
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20, 20))
colors = plt.cm.viridis(np.linspace(0, 1, 7))
pd.crosstab(smokers['highest_qualification'], smoking['gender']).plot(kind='barh', color=colors)
plt.xticks(rotation=45)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plt.figure(figsize=(20, 20))
colors = plt.cm.viridis(np.linspace(0, 1, 7))
pd.crosstab(smokers['ethnicity'], smoking['gender']).plot(kind='barh', color=colors)
plt.xticks(rotation=45)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plt.figure(figsize=(20, 20))
colors = plt.cm.viridis(np.linspace(0, 1, 5))
pd.crosstab(smokers['ethnicity'], smoking['gender']).plot(kind='barh', color=colors)
plt.xticks(rotation=45)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plt.figure(figsize=(20, 20))
colors = plt.cm.viridis(np.linspace(0, 1, 7))
pd.crosstab(smokers['gross_income'], smoking['gender']).plot(kind='barh', color=colors)
plt.xticks(rotation=45)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plt.figure(figsize=(20, 20))
colors = plt.cm.viridis(np.linspace(0, 1, 7))
pd.crosstab(smokers['region'], smoking['gender']).plot(kind='barh', color=colors)
plt.xticks(rotation=45)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# # The End if it useful notebook please upvote.....
